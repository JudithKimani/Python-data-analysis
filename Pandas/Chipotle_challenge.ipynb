# %%
import pandas as pd

# %% [markdown]
# url = https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv

# %%
#url =https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv

df= pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep='\t' )

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# Assign it to a variable called chipo.

# %%
chipo= pd.DataFrame(df)

print(chipo)

# %% [markdown]
# How many products cost more than $10.00?

# %%
expensive_products = (chipo['item_price'] > "10.00").sum()

# %% [markdown]
# What is the price of each item?
# print a data frame with only two columns item_name and item_price

# %%
price_item= chipo[['item_name','item_price']]

# %%
price_item.head()
# Out:
#                                item_name item_price
# 0           Chips and Fresh Tomato Salsa     $2.39
# 1                                   Izze     $3.39
# 2                       Nantucket Nectar     $3.39
# 3  Chips and Tomatillo-Green Chili Salsa     $2.39
# 4                           Chicken Bowl    $16.98

# %% [markdown]
# Sort by the name of the item

# %%
sorted_items= chipo.sort_values(by=['item_name'])

# %%
sorted_items.head()
# Out:
#       order_id  quantity          item_name choice_description item_price
# 3389      1360         2  6 Pack Soft Drink        [Diet Coke]    $12.98
# 341        148         1  6 Pack Soft Drink        [Diet Coke]     $6.49
# 1849       749         1  6 Pack Soft Drink             [Coke]     $6.49
# 1860       754         1  6 Pack Soft Drink        [Diet Coke]     $6.49
# 2713      1076         1  6 Pack Soft Drink             [Coke]     $6.49

# %% [markdown]
# What was the quantity of the most expensive item ordered?

# %%
most_expensive= chipo[['quantity','item_price']].max()

# %%
most_expensive.head()
# Out:
# quantity          15
# item_price    $9.39
# dtype: object

# %% [markdown]
# How many times was a Veggie Salad Bowl ordered?

# %%
veggie_orders = chipo[chipo['item_name'] == 'Veggie Salad Bowl']

veggie_quantity = veggie_salad_orders['quantity'].sum()

# %%
print(veggie_quantity)
# Out:
# 18

# %% [markdown]
# How many times did someone order more than one Canned Soda?

# %%
canned_soda= chipo[(chipo['item_name'] == 'Canned Soda') & (df['quantity'] > 1)]

num_canned_soda = canned_soda.shape[0]

print(num_canned_soda)
# Out:
# 20
